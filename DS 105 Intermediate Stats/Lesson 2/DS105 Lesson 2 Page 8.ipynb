# %%
### Importing packages 
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import ttest_ind

# %% [markdown]
# ### IMPORT DATA

# %%
ship = pd.read_excel("/Users/britfathi/Downloads/cruise_ship 3.xlsx")

# %% [markdown]
# ## NORMALITY CHECK

# %%
pd.options.display.max_columns = None
ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %%
sns.pairplot(ship)

# %% [markdown]
# ## TRANSFORMING POSITIVELY SKEWED DATA

# %% [markdown]
# ### Tonnage

# %%
ship['TonnageSQRT']= np.sqrt(ship['Tonnage'])

# %%
ship.TonnageSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Looks almost normal. Let me try another way. Logs?

# %%
ship['TonnageLOG']= np.log(ship['Tonnage'])

# %%
ship.TonnageLOG.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Not normal. Prefer the square root.

# %% [markdown]
# ### Cabins

# %%
ship['CabinsSQRT']= np.sqrt(ship['Cabins'])
ship.CabinsSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Looks close to normal

# %% [markdown]
# ### Passengers

# %%
ship['passngrsSQRT']= np.sqrt(ship['passngrs']) 
ship.passngrsSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Also normal-ish. From now on, I will assume it's normalish unless I say something different.

# %% [markdown]
# ### Crew

# %%
ship['CrewSQRT']= np.sqrt(ship['Crew']) 
ship.CrewSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# ### PassSpcR

# %%
ship['PassSpcRSQRT']= np.sqrt(ship['PassSpcR']) 
ship.PassSpcRSQRT.hist()
# Out:
# <Axes: >

# %%
ship['outcabSQRT']= np.sqrt(ship['outcab']) 
ship.outcabSQRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Not very normal. Try log?

# %%
ship['outcabLOG']= np.log(ship['outcab']) 
ship.outcabLOG.hist()
# Out:
# <Axes: >

# %%
ship['outcabCBRT']= np.cbrt(ship['outcab']) 
ship.outcabCBRT.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Nope. Worse. Leaving it alone for now...

# %% [markdown]
# ## TRANSFORMING NEGATIVELY SKEWED DATA

# %% [markdown]
# ### Year Built

# %%
ship['YearBltSQ']= ship['YearBlt'] **2
ship.YearBltSQ.hist()
# Out:
# <Axes: >

# %%
ship['YearBltCB']= ship['YearBlt'] **3
ship.YearBltCB.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Better, but not perfect.

# %% [markdown]
# ### Length

# %%
ship['LengthSQ']= ship['Length'] **2
ship.LengthSQ.hist()
# Out:
# <Axes: >

# %%
ship['LengthCB']= ship['Length'] **3
ship.LengthCB.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Square looks closer to normal.
